# %%
# %pip install streamlit
# Out:
# ...
#   Using cached streamlit-1.50.0-py3-none-any.whl (10.1 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.Collecting toml<2,>=0.10.1
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# ...
#
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# ...
#   ERROR: Can't roll back numpy; was not uninstalled
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\Users\\aanan\\AppData\\Local\\Programs\\Python\\Python39\\Lib\\site-packages\\numpy\\_core\\_machar.py'
# Consider using the `--user` option or check the permissions.
#
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the 'c:\Users\aanan\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
#   Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# ...
#   Using cached altair-5.5.0-py3-none-any.whl (731 kB)
# ...

# %%
import streamlit as st
import pandas as pd
import numpy as np

# %%
st.title("My First Streamlit App")
# Out:
# 2026-03-23 22:21:35.544 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-23 22:21:35.933
# ...
#   command:
#
#     streamlit run c:\Users\aanan\AppData\Local\Programs\Python\Python39\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-03-23 22:21:35.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-23 22:21:35.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
