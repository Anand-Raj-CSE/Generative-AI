# %% [markdown]
# There are 2 librari9es that we use - nltk and spacy . spaCy is designed for industry, offering superior speed and accuracy for production tasks using pre-trained models, while NLTK is tailored for education and research, providing a vast toolkit for customization
